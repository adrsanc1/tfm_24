# %%
import pandas as pd
import numpy as np
import os
import json
import seaborn as sns
import matplotlib.pyplot as plt
from utils import load, table_pivot, balanceo_smote, balanceo_total, completar
from itertools import combinations

# %% [markdown]
# # serum

# %%
df_study = load('./data/regularizacion/dataframe_serum_regularized.csv')

# %%
iDSamples = [x for x in enumerate(df_study.Sample)]
df_study.drop('Sample', axis=1, inplace=True)

# %%
lista = ['Cancer', 'Desc']
table_pivot(df_study,lista, lista[1], lista[0])
# Out:
# Cancer                                        False  True
# Desc
# Atypical leiomyoma                                0      1
# Brenner tumor                                     0      1
# Brenner tumor with mucinous cystadenofibroma      0      1
# Clear cell                                        0      1
# Control                                           6      0
# Endo-Clear Cell                                   0      9
# Endometrial Adenocarcinoma                        0      2
# Endometrioid                                      0      5
# Endometrioma                                      0      6
# Epithelioid Leiomyosarcoma                        0      1
# Fibroma                                           0      1
# Fibrothecoma                                      0      1
# Granulosa Cell                                    0      1
# Leiomyoma                                         0      1
# Mixed Mullerian adenofibroma                      0      1
# Mucinous                                          0      4
# Myxoid Leiomyosarcoma                             0      1
# Serous                                            0     59
# Simple cyst                                       0      1
# breast cancer tumor serum                         0      1
# serum from healthy woman control                  1      0

# %%
print(f'Filtro aquellos tipos de cáncer que se repiten menos de 2 veces')
# Out:
# Filtro aquellos tipos de cáncer que se repiten menos de 2 veces

# %%
subclases = [x[0] for x in (df_study.Desc.value_counts()>2).items() if x[1]==True]

df_study = df_study[(df_study.Desc.isin(subclases))].copy()
df_study.reset_index(drop=True, inplace=True)

# %%
print(df_study.Cancer.value_counts())
# Out:
# Cancer
# True     83
# False     6
# Name: count, dtype: int64

# %% [markdown]
# ## Normalizo

# %%
from sklearn.preprocessing import MinMaxScaler

# Inicializar el escalador MinMax
scaler = MinMaxScaler()

# Normalizar los datos del DataFrame
variables_miR_norm = pd.DataFrame(scaler.fit_transform(df_study.iloc[:,5:]), columns=df_study.iloc[:,5:].columns)

df_study = pd.concat([df_study.iloc[:,:5],variables_miR_norm],axis=1)

df_study.tail(2)
# Out:
#        Sex  Fluid  Cancer  Exosome     Desc  hsa-miR-6850-3p  hsa-miR-4761-3p  \
# 87  female  serum   False    False  Control              0.0              1.0
# 88  female  serum    True    False   Serous              0.0              0.0
#
#     hsa-miR-99b-3p  hsa-miR-3129-5p  hsa-miR-6820-5p  ...  hsa-miR-2467-3p  \
# 87        0.089665              0.0              0.0  ...              0.0
# 88        0.834784              1.0              0.0  ...              0.0
#
#     hsa-miR-6512-5p  hsa-miR-6718-5p  hsa-miR-520h  hsa-miR-6796-5p  \
# 87              0.0              0.0           0.0              0.0
# 88              0.0              0.0           0.0              0.0
#
#     hsa-miR-1245b-5p  hsa-miR-5586-3p  hsa-miR-29a-5p  hsa-miR-1304-3p  \
# 87               0.0              0.0             0.0         0.394581
# 88               0.0              0.0             0.0         0.558107
#
#     hsa-miR-384
# 87          0.0
# 88          0.0
#
# [2 rows x 1951 columns]

# %% [markdown]
# ## Balanceo datos

# %%
lista = ['Sex','Cancer']
table_pivot(df_study, lista, lista[0], lista[1])
# Out:
# Cancer  False  True
# Sex
# female      6     83

# %%
lista = ['Sex','Desc']
table_pivot(df_study, lista, lista[0], lista[1])
# Out:
# Desc    Control  Endo-Clear Cell  Endometrioid  Endometrioma  Mucinous  Serous
# Sex
# female        6                9             5             6         4      59

# %%
lista = ['Sex','Desc', 'Exosome']
table_pivot(df_study, lista, lista[0], lista[1:])
# Out:
# Desc    Control Endo-Clear Cell Endometrioid Endometrioma Mucinous Serous
# Exosome   False           False        False        False    False  False
# Sex
# female        6               9            5            6        4     59

# %%
from itertools import combinations

combinacion = list(combinations(df_study.Desc.unique(),2))
combinacion_se = [comb for comb in combinacion if df_study.Desc.value_counts().idxmax() in comb]
combinacion_se
# Out:
# [('Serous', 'Mucinous'),
#  ('Serous', 'Endometrioid'),
#  ('Serous', 'Control'),
#  ('Serous', 'Endometrioma'),
#  ('Serous', 'Endo-Clear Cell')]

# %%
df_prueba = df_study.copy()
for sex in df_study.Sex.unique():
    for comb1, comb2 in combinacion_se:
        df1 = df_prueba[(df_prueba.Desc==comb1) | (df_prueba.Desc==comb2)].reset_index(drop=True)
        df1 = df1[df1.Sex==sex].copy()
        #print(comb1,comb2, sex)
        if df1.Desc.nunique()>1:
            try:
                df_minoritario = balanceo_total(df1,'Desc',4)
            except:
                df_minoritario = balanceo_smote(df1,'Desc')
            df_prueba = completar(df_prueba,'Desc', df_minoritario, df1)
        else:
            pass
    df_prueba['Cancer'] = (df_prueba.Cancer).astype(bool)
#df_minoritario=balanceo_smote(df_prueba, 'Cancer')
#df_prueba=completar(df_prueba,'Cancer', df_minoritario, df_prueba)

# %%
df_prueba.Desc.value_counts()
# Out:
# Desc
# Endo-Clear Cell    61
# Mucinous           60
# Control            60
# Serous             59
# Endometrioid       58
# Endometrioma       58
# Name: count, dtype: int64

# %%
lista = ['Sex','Desc']
table_pivot(df_prueba, lista, lista[0], lista[1:])
# Out:
# Desc    Control  Endo-Clear Cell  Endometrioid  Endometrioma  Mucinous  Serous
# Sex
# female       60               61            58            58        60      59

# %%
lista = ['Sex','Desc', 'Exosome']
table_pivot(df_prueba, lista, lista[0], lista[1:])
# Out:
# Desc    Control Endo-Clear Cell Endometrioid Endometrioma Mucinous Serous
# Exosome   False           False        False        False    False  False
# Sex
# female       60              61           58           58       60     59

# %%
df_study = df_prueba.copy()

# %%
df_study.to_csv('./data/Normalizado_serum.csv', index=False)

# %% [markdown]
# ## Estadísticos

# %% [markdown]
# ### Homocedasticidad

# %%
from utils import Homocedasticity

homoc = Homocedasticity(df_study.iloc[:,5:])

# %%
homoc.verify()
# Out:
# Homocedasticidad de las columnas: False

# %% [markdown]
# **Distribucion**

# %%
import sweetviz as sv

df=df_study.iloc[:,5:56].copy()

# Generar el informe
reporte = sv.analyze(df)

folder = './figures/serum'

# Mostrar el informe en un navegador
reporte.show_html(f'{folder}/Distribucion_report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report ./figures/serum/Distribucion_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# from skimpy import skim
#
# skim(df)

# %% [markdown]
# **Varianzas**

# %%
varianzas = homoc.varianza()

# %%
homoc.boxplot()

# %% [markdown]
# **Seleccionar varianzas distintas de 0**

# %%
df_varianza = homoc.dataframe()

# %%
variables = [i for i in df_varianza.columns if df_varianza.loc[0,i]>0]
len(variables)
# Out:
# 1763

# %% [markdown]
# **Seleccionar varianzas filtradas**

# %%
filtroBajo = df_varianza.T.describe().loc['25%',0]
filtroAlto = (df_varianza.T.describe().loc['75%',0] + df_varianza.T.describe().loc['50%',0])/2

variablesAcotadas = [col for col in df_varianza.columns if  filtroAlto > df_varianza.loc[0,col] > filtroBajo]
len(variablesAcotadas)
# Out:
# 721

# %%
df_study = pd.concat([df_study.iloc[:,:5], df_study.loc[:,variablesAcotadas]], axis=1)

# %%
variables = variablesAcotadas

# %% [markdown]
# ### Kruskal-Wallis

# %%
variables.append('Desc')
#varianzas.remove('Desc')
df = df_study[variables].copy()

# %%
from scipy.stats import kruskal
import scikit_posthocs as sp

# Separar las características y la variable objetivo
X = df.iloc[:,:-1]
y = df['Desc']

# Lista para almacenar los resultados de las pruebas de Dunn
dunn_results = {}

significant_features = []

# Aplicar la prueba de Kruskal-Wallis a cada característica
p_values = []
for column in X.columns:
    # Obtener las muestras para cada clase
    samples = [X[column][y == cls].values for cls in y.unique()]
    stat, p_value = kruskal(*samples)
    p_values.append((column, p_value))
    
    # Si la prueba de Kruskal-Wallis es significativa (p < 0.05), aplicar la prueba de Dunn
    if p_value < 0.05:
        # Combinar X y y en un DataFrame para la prueba de Dunn
        data = pd.DataFrame({
            'values': X[column],
            'group': y
        })
        
        # Aplicar la prueba de Dunn con ajuste de Bonferroni para comparaciones múltiples
        dunn_result = sp.posthoc_dunn(data, val_col='values', group_col='group', p_adjust='bonferroni')
        
        # Almacenar el resultado de la prueba de Dunn
        dunn_results[column] = dunn_result


# Mostrar los resultados de la prueba de Dunn
for feature, result in dunn_results.items():
    print(f"Prueba de Dunn para la característica: {feature}")
    print(result)
# Out:
# Prueba de Dunn para la característica: hsa-miR-4761-3p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00         0.357421  1.766873e-10  1.766873e-10
# Endo-Clear Cell  3.574214e-01         1.000000  7.319736e-05  7.319736e-05
# Endometrioid     1.766873e-10         0.000073  1.000000e+00  1.000000e+00
# Endometrioma     1.766873e-10         0.000073  1.000000e+00  1.000000e+00
# Mucinous         1.178663e-10         0.000061  1.000000e+00  1.000000e+00
# Serous           2.901458e-08         0.002376  1.000000e+00  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.178663e-10  2.901458e-08
# Endo-Clear Cell  6.056351e-05  2.376349e-03
# Endometrioid     1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-3129-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     2.313486e-11  6.837094e-07  1.000000e+00
# Endo-Clear Cell  2.313486e-11     1.000000e+00  1.000000e+00  3.575745e-11
# Endometrioid     6.837094e-07     1.000000e+00  1.000000e+00  8.841104e-07
# Endometrioma     1.000000e+00     3.575745e-11  8.841104e-07  1.000000e+00
# Mucinous         1.000000e+00     2.313486e-11  6.837094e-07  1.000000e+00
# Serous           1.000000e+00     1.651833e-09  1.723875e-05  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.000000e+00  1.000000e+00
# Endo-Clear Cell  2.313486e-11  1.651833e-09
# Endometrioid     6.837094e-07  1.723875e-05
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-4731-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  1.000000e+00  2.787603e-11
# Endo-Clear Cell  1.000000e+00     1.000000e+00  1.000000e+00  2.269852e-11
# Endometrioid     1.000000e+00     1.000000e+00  1.000000e+00  4.249669e-11
# Endometrioma     2.787603e-11     2.269852e-11  4.249669e-11  1.000000e+00
# Mucinous         1.000000e+00     1.000000e+00  1.000000e+00  2.787603e-11
# Serous           9.151377e-01     8.993970e-01  9.483517e-01  3.745290e-06
#
#                      Mucinous    Serous
# Control          1.000000e+00  0.915138
# Endo-Clear Cell  1.000000e+00  0.899397
# Endometrioid     1.000000e+00  0.948352
# Endometrioma     2.787603e-11  0.000004
# Mucinous         1.000000e+00  0.915138
# Serous           9.151377e-01  1.000000
# Prueba de Dunn para la característica: hsa-miR-136-5p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000     1.415862e-05  3.345010e-01  1.668654e-04
# Endo-Clear Cell  0.000014     1.000000e+00  1.251461e-11  1.000000e+00
# Endometrioid     0.334501     1.251461e-11  1.000000e+00  5.265389e-10
# Endometrioma     0.000167     1.000000e+00  5.265389e-10  1.000000e+00
# Mucinous         1.000000     1.057737e-04  1.068867e-01  9.978571e-04
# Serous           1.000000     4.428543e-03  6.406919e-03  2.631774e-02
#
#                  Mucinous    Serous
# Control          1.000000  1.000000
# Endo-Clear Cell  0.000106  0.004429
# Endometrioid     0.106887  0.006407
# Endometrioma     0.000998  0.026318
# Mucinous         1.000000  1.000000
# Serous           1.000000  1.000000
# Prueba de Dunn para la característica: hsa-miR-4677-5p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000         0.957760      1.000000      1.000000
# Endo-Clear Cell  0.957760         1.000000      0.058553      0.289116
# Endometrioid     1.000000         0.058553      1.000000      1.000000
# Endometrioma     1.000000         0.289116      1.000000      1.000000
# Mucinous         1.000000         1.000000      1.000000      1.000000
# Serous           0.403344         1.000000      0.018284      0.106156
#
#                  Mucinous    Serous
# Control          1.000000  0.403344
# Endo-Clear Cell  1.000000  1.000000
# Endometrioid     1.000000  0.018284
# Endometrioma     1.000000  0.106156
# Mucinous         1.000000  0.895153
# Serous           0.895153  1.000000
# Prueba de Dunn para la característica: hsa-miR-6766-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.639222e-10  1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.639222e-10     1.000000e+00  2.451783e-10  2.451783e-10
# Endometrioid     1.000000e+00     2.451783e-10  1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00     2.451783e-10  1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00     1.639222e-10  1.000000e+00  1.000000e+00
# Serous           1.000000e+00     4.605427e-08  1.000000e+00  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.639222e-10  4.605427e-08
# Endometrioid     1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-6869-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioid     1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Mucinous         1.465771e-19     1.018157e-19  3.094997e-19  3.094997e-19
# Serous           1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.465771e-19  1.000000e+00
# Endo-Clear Cell  1.018157e-19  1.000000e+00
# Endometrioid     3.094997e-19  1.000000e+00
# Endometrioma     3.094997e-19  1.000000e+00
# Mucinous         1.000000e+00  2.042411e-15
# Serous           2.042411e-15  1.000000e+00
# Prueba de Dunn para la característica: Hsa-Mir-3085_3p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00      0.000002  1.000000e+00
# Endo-Clear Cell  1.000000e+00     1.000000e+00      0.000002  1.000000e+00
# Endometrioid     1.946725e-06     1.731790e-06      1.000000  2.475091e-06
# Endometrioma     1.000000e+00     1.000000e+00      0.000002  1.000000e+00
# Mucinous         9.354372e-11     7.664675e-11      1.000000  1.407664e-10
# Serous           3.675341e-01     3.588510e-01      0.037034  3.860351e-01
#
#                      Mucinous    Serous
# Control          9.354372e-11  0.367534
# Endo-Clear Cell  7.664675e-11  0.358851
# Endometrioid     1.000000e+00  0.037034
# Endometrioma     1.407664e-10  0.386035
# Mucinous         1.000000e+00  0.000065
# Serous           6.458908e-05  1.000000
# Prueba de Dunn para la característica: hsa-miR-26a-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     2.177514e-18  2.583790e-17  1.360384e-19
# Endo-Clear Cell  2.177514e-18     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioid     2.583790e-17     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioma     1.360384e-19     1.000000e+00  1.000000e+00  1.000000e+00
# Mucinous         6.778798e-14     1.000000e+00  1.000000e+00  1.000000e+00
# Serous           2.473783e-15     1.000000e+00  1.000000e+00  1.000000e+00
#
#                      Mucinous        Serous
# Control          6.778798e-14  2.473783e-15
# Endo-Clear Cell  1.000000e+00  1.000000e+00
# Endometrioid     1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-885-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00         0.000118  6.816237e-12  9.176892e-07
# Endo-Clear Cell  1.180770e-04         1.000000  6.824124e-02  1.000000e+00
# Endometrioid     6.816237e-12         0.068241  1.000000e+00  1.000000e+00
# Endometrioma     9.176892e-07         1.000000  1.000000e+00  1.000000e+00
# Mucinous         5.282063e-09         1.000000  1.000000e+00  1.000000e+00
# Serous           6.391369e-02         1.000000  1.827613e-04  1.575262e-01
#
#                      Mucinous    Serous
# Control          5.282063e-09  0.063914
# Endo-Clear Cell  1.000000e+00  1.000000
# Endometrioid     1.000000e+00  0.000183
# Endometrioma     1.000000e+00  0.157526
# Mucinous         1.000000e+00  0.010511
# Serous           1.051059e-02  1.000000
# Prueba de Dunn para la característica: hsa-miR-3129-3p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000     9.276900e-02  3.010982e-02  1.029570e-01
# Endo-Clear Cell  0.092769     1.000000e+00  9.040463e-08  1.000000e+00
# Endometrioid     0.030110     9.040463e-08  1.000000e+00  1.386543e-07
# Endometrioma     0.102957     1.000000e+00  1.386543e-07  1.000000e+00
# Mucinous         0.002929     1.391582e-09  1.000000e+00  2.380483e-09
# Serous           0.461784     1.000000e+00  2.713527e-06  1.000000e+00
#
#                      Mucinous        Serous
# Control          2.928664e-03  4.617839e-01
# Endo-Clear Cell  1.391582e-09  1.000000e+00
# Endometrioid     1.000000e+00  2.713527e-06
# Endometrioma     2.380483e-09  1.000000e+00
# Mucinous         1.000000e+00  6.566956e-08
# Serous           6.566956e-08  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-518f-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.727030e-11  3.289950e-11  3.289950e-11
# Endo-Clear Cell  1.727030e-11     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioid     3.289950e-11     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioma     3.289950e-11     1.000000e+00  1.000000e+00  1.000000e+00
# Mucinous         2.133179e-11     1.000000e+00  1.000000e+00  1.000000e+00
# Serous           7.937640e-09     1.000000e+00  1.000000e+00  1.000000e+00
#
#                      Mucinous        Serous
# Control          2.133179e-11  7.937640e-09
# Endo-Clear Cell  1.000000e+00  1.000000e+00
# Endometrioid     1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-let-7i-5p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000         0.000145      1.000000      1.000000
# Endo-Clear Cell  0.000145         1.000000      0.000003      0.001324
# Endometrioid     1.000000         0.000003      1.000000      1.000000
# Endometrioma     1.000000         0.001324      1.000000      1.000000
# Mucinous         1.000000         0.019659      0.704788      1.000000
# Serous           1.000000         0.000012      1.000000      1.000000
#
#                  Mucinous    Serous
# Control          1.000000  1.000000
# Endo-Clear Cell  0.019659  0.000012
# Endometrioid     0.704788  1.000000
# Endometrioma     1.000000  1.000000
# Mucinous         1.000000  1.000000
# Serous           1.000000  1.000000
# Prueba de Dunn para la característica: hsa-miR-6820-3p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000         0.000021      0.000028      0.000028
# Endo-Clear Cell  0.000021         1.000000      1.000000      1.000000
# Endometrioid     0.000028         1.000000      1.000000      1.000000
# Endometrioma     0.000028         1.000000      1.000000      1.000000
# Mucinous         0.000023         1.000000      1.000000      1.000000
# Serous           0.172898         0.349163      0.375840      0.375840
#
#                  Mucinous    Serous
# Control          0.000023  0.172898
# Endo-Clear Cell  1.000000  0.349163
# Endometrioid     1.000000  0.375840
# Endometrioma     1.000000  0.375840
# Mucinous         1.000000  0.357682
# Serous           0.357682  1.000000
# Prueba de Dunn para la característica: hsa-miR-4701-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  5.682756e-28  1.000000e+00
# Endo-Clear Cell  1.000000e+00     1.000000e+00  3.398623e-28  1.000000e+00
# Endometrioid     5.682756e-28     3.398623e-28  1.000000e+00  1.631783e-27
# Endometrioma     1.000000e+00     1.000000e+00  1.631783e-27  1.000000e+00
# Mucinous         1.000000e+00     1.000000e+00  5.682756e-28  1.000000e+00
# Serous           6.549792e-01     6.421820e-01  7.795217e-19  6.820773e-01
#
#                      Mucinous        Serous
# Control          1.000000e+00  6.549792e-01
# Endo-Clear Cell  1.000000e+00  6.421820e-01
# Endometrioid     5.682756e-28  7.795217e-19
# Endometrioma     1.000000e+00  6.820773e-01
# Mucinous         1.000000e+00  6.549792e-01
# Serous           6.549792e-01  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-136-3p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000          0.00002       0.00077      0.046952
# Endo-Clear Cell  0.000020          1.00000       1.00000      1.000000
# Endometrioid     0.000770          1.00000       1.00000      1.000000
# Endometrioma     0.046952          1.00000       1.00000      1.000000
# Mucinous         0.000027          1.00000       1.00000      1.000000
# Serous           0.015865          1.00000       1.00000      1.000000
#
#                  Mucinous    Serous
# Control          0.000027  0.015865
# Endo-Clear Cell  1.000000  1.000000
# Endometrioid     1.000000  1.000000
# Endometrioma     1.000000  1.000000
# Mucinous         1.000000  1.000000
# Serous           1.000000  1.000000
# Prueba de Dunn para la característica: hsa-miR-3074-5p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000         1.000000      0.035813      0.548041
# Endo-Clear Cell  1.000000         1.000000      0.227223      1.000000
# Endometrioid     0.035813         0.227223      1.000000      1.000000
# Endometrioma     0.548041         1.000000      1.000000      1.000000
# Mucinous         0.013051         0.098782      1.000000      1.000000
# Serous           1.000000         1.000000      0.447077      1.000000
#
#                  Mucinous    Serous
# Control          0.013051  1.000000
# Endo-Clear Cell  0.098782  1.000000
# Endometrioid     1.000000  0.447077
# Endometrioma     1.000000  1.000000
# Mucinous         1.000000  0.210611
# Serous           0.210611  1.000000
# Prueba de Dunn para la característica: hsa-miR-3177-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  1.257387e-13  1.000000e+00
# Endo-Clear Cell  1.000000e+00     1.000000e+00  9.806188e-14  1.000000e+00
# Endometrioid     1.257387e-13     9.806188e-14  1.000000e+00  2.094274e-13
# Endometrioma     1.000000e+00     1.000000e+00  2.094274e-13  1.000000e+00
# Mucinous         1.000000e+00     1.000000e+00  1.257387e-13  1.000000e+00
# Serous           1.000000e+00     1.000000e+00  7.358725e-10  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.000000e+00  1.000000e+00
# Endometrioid     1.257387e-13  7.358725e-10
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-199a-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     4.295091e-11  2.516566e-18  4.394920e-16
# Endo-Clear Cell  4.295091e-11     1.000000e+00  4.795528e-01  1.000000e+00
# Endometrioid     2.516566e-18     4.795528e-01  1.000000e+00  1.000000e+00
# Endometrioma     4.394920e-16     1.000000e+00  1.000000e+00  1.000000e+00
# Mucinous         2.359814e-03     2.138030e-02  1.880840e-06  3.859294e-05
# Serous           1.640018e-12     1.000000e+00  1.000000e+00  1.000000e+00
#
#                  Mucinous        Serous
# Control          0.002360  1.640018e-12
# Endo-Clear Cell  0.021380  1.000000e+00
# Endometrioid     0.000002  1.000000e+00
# Endometrioma     0.000039  1.000000e+00
# Mucinous         1.000000  3.698513e-03
# Serous           0.003699  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-106b-3p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000     1.695979e-04  8.327720e-02  2.941795e-05
# Endo-Clear Cell  0.000170     1.000000e+00  1.428171e-11  1.000000e+00
# Endometrioid     0.083277     1.428171e-11  1.000000e+00  1.225947e-12
# Endometrioma     0.000029     1.000000e+00  1.225947e-12  1.000000e+00
# Mucinous         0.000004     1.964350e-20  3.047868e-01  1.018739e-21
# Serous           1.000000     3.188623e-03  9.336450e-03  6.822453e-04
#
#                      Mucinous        Serous
# Control          4.181482e-06  1.000000e+00
# Endo-Clear Cell  1.964350e-20  3.188623e-03
# Endometrioid     3.047868e-01  9.336450e-03
# Endometrioma     1.018739e-21  6.822453e-04
# Mucinous         1.000000e+00  1.112288e-07
# Serous           1.112288e-07  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-21-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     7.649817e-18  2.403351e-29  5.183571e-10
# Endo-Clear Cell  7.649817e-18     1.000000e+00  1.052251e-01  4.376944e-01
# Endometrioid     2.403351e-29     1.052251e-01  1.000000e+00  2.187702e-05
# Endometrioma     5.183571e-10     4.376944e-01  2.187702e-05  1.000000e+00
# Mucinous         2.702918e-07     1.689885e-02  5.415981e-08  1.000000e+00
# Serous           1.053479e-10     7.037885e-01  5.318840e-05  1.000000e+00
#
#                      Mucinous        Serous
# Control          2.702918e-07  1.053479e-10
# Endo-Clear Cell  1.689885e-02  7.037885e-01
# Endometrioid     5.415981e-08  5.318840e-05
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-let-7i-3p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000     4.515533e-01  5.571390e-06  3.550642e-02
# Endo-Clear Cell  0.451553     1.000000e+00  6.079985e-12  1.000000e+00
# Endometrioid     0.000006     6.079985e-12  1.000000e+00  1.193102e-14
# Endometrioma     0.035506     1.000000e+00  1.193102e-14  1.000000e+00
# Mucinous         0.387956     1.578247e-04  6.084252e-02  2.292406e-06
# Serous           0.499543     2.601162e-04  4.742640e-02  4.171868e-06
#
#                  Mucinous    Serous
# Control          0.387956  0.499543
# Endo-Clear Cell  0.000158  0.000260
# Endometrioid     0.060843  0.047426
# Endometrioma     0.000002  0.000004
# Mucinous         1.000000  1.000000
# Serous           1.000000  1.000000
# Prueba de Dunn para la característica: hsa-miR-548o-3p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00         0.023354  2.208184e-08      1.000000
# Endo-Clear Cell  2.335374e-02         1.000000  5.000189e-02      1.000000
# Endometrioid     2.208184e-08         0.050002  1.000000e+00      0.000112
# Endometrioma     1.000000e+00         1.000000  1.117082e-04      1.000000
# Mucinous         1.000000e+00         0.660249  1.352763e-05      1.000000
# Serous           1.000000e+00         0.292978  2.722970e-06      1.000000
#
#                  Mucinous    Serous
# Control          1.000000  1.000000
# Endo-Clear Cell  0.660249  0.292978
# Endometrioid     0.000014  0.000003
# Endometrioma     1.000000  1.000000
# Mucinous         1.000000  1.000000
# Serous           1.000000  1.000000
# Prueba de Dunn para la característica: hsa-miR-4794
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  1.114650e-16  1.000000e+00
# Endo-Clear Cell  1.000000e+00     1.000000e+00  8.217138e-17  1.000000e+00
# Endometrioid     1.114650e-16     8.217138e-17  1.000000e+00  2.083853e-16
# Endometrioma     1.000000e+00     1.000000e+00  2.083853e-16  1.000000e+00
# Mucinous         1.000000e+00     1.000000e+00  1.114650e-16  1.000000e+00
# Serous           1.000000e+00     1.000000e+00  5.688630e-14  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.000000e+00  1.000000e+00
# Endometrioid     1.114650e-16  5.688630e-14
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-517-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioid     1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Mucinous         6.702998e-21     4.540058e-21  1.490504e-20  1.490504e-20
# Serous           1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
#
#                      Mucinous        Serous
# Control          6.702998e-21  1.000000e+00
# Endo-Clear Cell  4.540058e-21  1.000000e+00
# Endometrioid     1.490504e-20  1.000000e+00
# Endometrioma     1.490504e-20  1.000000e+00
# Mucinous         1.000000e+00  2.912378e-19
# Serous           2.912378e-19  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-3074-3p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00         0.000991  1.000000e+00  1.000000e+00
# Endo-Clear Cell  9.912392e-04         1.000000  1.144511e-03  1.144511e-03
# Endometrioid     1.000000e+00         0.001145  1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00         0.001145  1.000000e+00  1.000000e+00
# Mucinous         2.336753e-12         0.009304  3.739110e-12  3.739110e-12
# Serous           7.341564e-01         0.689178  7.632510e-01  7.632510e-01
#
#                      Mucinous    Serous
# Control          2.336753e-12  0.734156
# Endo-Clear Cell  9.303801e-03  0.689178
# Endometrioid     3.739110e-12  0.763251
# Endometrioma     3.739110e-12  0.763251
# Mucinous         1.000000e+00  0.000001
# Serous           1.105185e-06  1.000000
# Prueba de Dunn para la característica: hsa-miR-4791
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.598524e-06  6.803545e-07  1.000000e+00
# Endo-Clear Cell  1.598524e-06     1.000000e+00  7.947285e-26  3.433654e-04
# Endometrioid     6.803545e-07     7.947285e-26  1.000000e+00  1.734624e-09
# Endometrioma     1.000000e+00     3.433654e-04  1.734624e-09  1.000000e+00
# Mucinous         2.471300e-02     3.511426e-16  2.830856e-01  4.959047e-04
# Serous           1.000000e+00     1.571181e-04  3.913880e-09  1.000000e+00
#
#                      Mucinous        Serous
# Control          2.471300e-02  1.000000e+00
# Endo-Clear Cell  3.511426e-16  1.571181e-04
# Endometrioid     2.830856e-01  3.913880e-09
# Endometrioma     4.959047e-04  1.000000e+00
# Mucinous         1.000000e+00  8.881009e-04
# Serous           8.881009e-04  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-196a-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00         0.000718  2.088826e-09      1.000000
# Endo-Clear Cell  7.182760e-04         1.000000  2.380556e-01      0.137670
# Endometrioid     2.088826e-09         0.238056  1.000000e+00      0.000011
# Endometrioma     1.000000e+00         0.137670  1.084044e-05      1.000000
# Mucinous         4.335384e-07         1.000000  1.000000e+00      0.000673
# Serous           1.000000e+00         0.058876  2.404254e-06      1.000000
#
#                      Mucinous    Serous
# Control          4.335384e-07  1.000000
# Endo-Clear Cell  1.000000e+00  0.058876
# Endometrioid     1.000000e+00  0.000002
# Endometrioma     6.725929e-04  1.000000
# Mucinous         1.000000e+00  0.000191
# Serous           1.906797e-04  1.000000
# Prueba de Dunn para la característica: hsa-miR-3689a-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     8.949037e-08  1.382852e-07  1.382852e-07
# Endo-Clear Cell  8.949037e-08     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioid     1.382852e-07     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioma     1.382852e-07     1.000000e+00  1.000000e+00  1.000000e+00
# Mucinous         1.032078e-07     1.000000e+00  1.000000e+00  1.000000e+00
# Serous           1.193172e-07     1.000000e+00  1.000000e+00  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.032078e-07  1.193172e-07
# Endo-Clear Cell  1.000000e+00  1.000000e+00
# Endometrioid     1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-326
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00         0.000052  2.497238e-16  1.281251e-08
# Endo-Clear Cell  5.202947e-05         1.000000  1.179679e-03  1.000000e+00
# Endometrioid     2.497238e-16         0.001180  1.000000e+00  2.736561e-01
# Endometrioma     1.281251e-08         1.000000  2.736561e-01  1.000000e+00
# Mucinous         6.157028e-13         0.047994  1.000000e+00  1.000000e+00
# Serous           3.400653e-08         1.000000  1.602618e-01  1.000000e+00
#
#                      Mucinous        Serous
# Control          6.157028e-13  3.400653e-08
# Endo-Clear Cell  4.799415e-02  1.000000e+00
# Endometrioid     1.000000e+00  1.602618e-01
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-4788
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000     5.825105e-02  1.253587e-02  1.253587e-02
# Endo-Clear Cell  0.058251     1.000000e+00  7.604634e-09  7.604634e-09
# Endometrioid     0.012536     7.604634e-09  1.000000e+00  1.000000e+00
# Endometrioma     0.012536     7.604634e-09  1.000000e+00  1.000000e+00
# Mucinous         0.011301     5.390237e-09  1.000000e+00  1.000000e+00
# Serous           0.101281     3.306845e-07  1.000000e+00  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.130147e-02  1.012811e-01
# Endo-Clear Cell  5.390237e-09  3.306845e-07
# Endometrioid     1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-4785
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  3.540134e-11  1.000000e+00
# Endo-Clear Cell  1.000000e+00     1.000000e+00  3.160312e-16  1.000000e+00
# Endometrioid     3.540134e-11     3.160312e-16  1.000000e+00  1.592478e-10
# Endometrioma     1.000000e+00     1.000000e+00  1.592478e-10  1.000000e+00
# Mucinous         1.000000e+00     1.000000e+00  1.558295e-10  1.000000e+00
# Serous           1.000000e+00     1.000000e+00  1.958586e-14  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.000000e+00  1.000000e+00
# Endometrioid     1.558295e-10  1.958586e-14
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-4784
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000         0.000029      0.000038      0.000038
# Endo-Clear Cell  0.000029         1.000000      1.000000      1.000000
# Endometrioid     0.000038         1.000000      1.000000      1.000000
# Endometrioma     0.000038         1.000000      1.000000      1.000000
# Mucinous         0.000031         1.000000      1.000000      1.000000
# Serous           0.448841         0.155628      0.170566      0.170566
#
#                  Mucinous    Serous
# Control          0.000031  0.448841
# Endo-Clear Cell  1.000000  0.155628
# Endometrioid     1.000000  0.170566
# Endometrioma     1.000000  0.170566
# Mucinous         1.000000  0.160370
# Serous           0.160370  1.000000
# Prueba de Dunn para la característica: hsa-miR-23a-3p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  7.600373e-27  3.147105e-02
# Endo-Clear Cell  1.000000e+00     1.000000e+00  7.234303e-20  1.000000e+00
# Endometrioid     7.600373e-27     7.234303e-20  1.000000e+00  7.177123e-14
# Endometrioma     3.147105e-02     1.000000e+00  7.177123e-14  1.000000e+00
# Mucinous         1.267420e-23     4.764521e-17  1.000000e+00  1.630525e-11
# Serous           8.765098e-14     7.170760e-09  2.151060e-02  4.342449e-05
#
#                      Mucinous        Serous
# Control          1.267420e-23  8.765098e-14
# Endo-Clear Cell  4.764521e-17  7.170760e-09
# Endometrioid     1.000000e+00  2.151060e-02
# Endometrioma     1.630525e-11  4.342449e-05
# Mucinous         1.000000e+00  2.252756e-01
# Serous           2.252756e-01  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-4798-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.543504e-17  1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.543504e-17     1.000000e+00  3.030939e-17  3.030939e-17
# Endometrioid     1.000000e+00     3.030939e-17  1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00     3.030939e-17  1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00     1.543504e-17  1.000000e+00  1.000000e+00
# Serous           1.000000e+00     1.038313e-14  1.000000e+00  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.543504e-17  1.038313e-14
# Endometrioid     1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-30d-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  7.665533e-13  5.022888e-09
# Endo-Clear Cell  1.000000e+00     1.000000e+00  5.257894e-08  4.893214e-05
# Endometrioid     7.665533e-13     5.257894e-08  1.000000e+00  1.000000e+00
# Endometrioma     5.022888e-09     4.893214e-05  1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00     1.000000e+00  1.169874e-10  3.312458e-07
# Serous           5.658065e-03     8.434394e-01  1.067412e-03  9.494947e-02
#
#                      Mucinous    Serous
# Control          1.000000e+00  0.005658
# Endo-Clear Cell  1.000000e+00  0.843439
# Endometrioid     1.169874e-10  0.001067
# Endometrioma     3.312458e-07  0.094949
# Mucinous         1.000000e+00  0.062417
# Serous           6.241686e-02  1.000000
# Prueba de Dunn para la característica: hsa-let-7f-1-3p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000     8.941731e-04      0.805969      1.000000
# Endo-Clear Cell  0.000894     1.000000e+00      0.615663      0.000951
# Endometrioid     0.805969     6.156627e-01      1.000000      0.799314
# Endometrioma     1.000000     9.506383e-04      0.799314      1.000000
# Mucinous         1.000000     2.230225e-07      0.005627      1.000000
# Serous           1.000000     1.812700e-02      1.000000      1.000000
#
#                      Mucinous    Serous
# Control          1.000000e+00  1.000000
# Endo-Clear Cell  2.230225e-07  0.018127
# Endometrioid     5.627013e-03  1.000000
# Endometrioma     1.000000e+00  1.000000
# Mucinous         1.000000e+00  0.251092
# Serous           2.510918e-01  1.000000
# Prueba de Dunn para la característica: hsa-miR-4779
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00         0.002021      0.005078  8.267955e-14
# Endo-Clear Cell  2.020605e-03         1.000000      1.000000  7.317401e-04
# Endometrioid     5.078191e-03         1.000000      1.000000  4.086379e-04
# Endometrioma     8.267955e-14         0.000732      0.000409  1.000000e+00
# Mucinous         4.843530e-14         0.000629      0.000349  1.000000e+00
# Serous           1.886356e-09         0.118248      0.074567  1.000000e+00
#
#                      Mucinous        Serous
# Control          4.843530e-14  1.886356e-09
# Endo-Clear Cell  6.290753e-04  1.182477e-01
# Endometrioid     3.493303e-04  7.456738e-02
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-196a-3p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00         0.050526  1.000000e+00  1.063419e-10
# Endo-Clear Cell  5.052619e-02         1.000000  5.477323e-02  1.047571e-03
# Endometrioid     1.000000e+00         0.054773  1.000000e+00  1.586061e-10
# Endometrioma     1.063419e-10         0.001048  1.586061e-10  1.000000e+00
# Mucinous         1.000000e+00         0.050526  1.000000e+00  1.063419e-10
# Serous           1.000000e+00         0.052588  1.000000e+00  1.296472e-10
#
#                      Mucinous        Serous
# Control          1.000000e+00  1.000000e+00
# Endo-Clear Cell  5.052619e-02  5.258847e-02
# Endometrioid     1.000000e+00  1.000000e+00
# Endometrioma     1.063419e-10  1.296472e-10
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-193a-5p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000         1.000000      1.000000  1.240309e-05
# Endo-Clear Cell  1.000000         1.000000      1.000000  2.336216e-02
# Endometrioid     1.000000         1.000000      1.000000  7.565339e-03
# Endometrioma     0.000012         0.023362      0.007565  1.000000e+00
# Mucinous         1.000000         0.007287      0.030251  6.355551e-10
# Serous           1.000000         1.000000      1.000000  9.395071e-03
#
#                      Mucinous    Serous
# Control          1.000000e+00  1.000000
# Endo-Clear Cell  7.287351e-03  1.000000
# Endometrioid     3.025110e-02  1.000000
# Endometrioma     6.355551e-10  0.009395
# Mucinous         1.000000e+00  0.022468
# Serous           2.246828e-02  1.000000
# Prueba de Dunn para la característica: hsa-miR-154-3p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000         0.011381      1.000000      0.000001
# Endo-Clear Cell  0.011381         1.000000      0.012633      0.642960
# Endometrioid     1.000000         0.012633      1.000000      0.000002
# Endometrioma     0.000001         0.642960      0.000002      1.000000
# Mucinous         1.000000         0.011381      1.000000      0.000001
# Serous           0.796312         1.000000      0.826886      0.010037
#
#                  Mucinous    Serous
# Control          1.000000  0.796312
# Endo-Clear Cell  0.011381  1.000000
# Endometrioid     1.000000  0.826886
# Endometrioma     0.000001  0.010037
# Mucinous         1.000000  0.796312
# Serous           0.796312  1.000000
# Prueba de Dunn para la característica: hsa-miR-4765
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  5.607767e-17      0.004241
# Endo-Clear Cell  1.000000e+00     1.000000e+00  4.111296e-17      0.004005
# Endometrioid     5.607767e-17     4.111296e-17  1.000000e+00      0.000008
# Endometrioma     4.240653e-03     4.005192e-03  8.016472e-06      1.000000
# Mucinous         1.000000e+00     1.000000e+00  5.607767e-17      0.004241
# Serous           5.157114e-01     5.047665e-01  8.470384e-10      1.000000
#
#                      Mucinous        Serous
# Control          1.000000e+00  5.157114e-01
# Endo-Clear Cell  1.000000e+00  5.047665e-01
# Endometrioid     5.607767e-17  8.470384e-10
# Endometrioma     4.240653e-03  1.000000e+00
# Mucinous         1.000000e+00  5.157114e-01
# Serous           5.157114e-01  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-1238-3p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000         0.052517      0.000001      1.000000
# Endo-Clear Cell  0.052517         1.000000      0.194848      0.814844
# Endometrioid     0.000001         0.194848      1.000000      0.000201
# Endometrioma     1.000000         0.814844      0.000201      1.000000
# Mucinous         1.000000         0.409840      0.000049      1.000000
# Serous           0.000033         0.975576      1.000000      0.002866
#
#                  Mucinous    Serous
# Control          1.000000  0.000033
# Endo-Clear Cell  0.409840  0.975576
# Endometrioid     0.000049  1.000000
# Endometrioma     1.000000  0.002866
# Mucinous         1.000000  0.000851
# Serous           0.000851  1.000000
# Prueba de Dunn para la característica: hsa-miR-3671
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioid     1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Mucinous         1.230019e-21     8.216364e-22  2.814048e-21  2.814048e-21
# Serous           1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.230019e-21  1.000000e+00
# Endo-Clear Cell  8.216364e-22  1.000000e+00
# Endometrioid     2.814048e-21  1.000000e+00
# Endometrioma     2.814048e-21  1.000000e+00
# Mucinous         1.000000e+00  1.853975e-21
# Serous           1.853975e-21  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-30d-3p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00         0.319715  1.090310e-08  1.000000e+00
# Endo-Clear Cell  3.197153e-01         1.000000  1.428178e-03  1.000000e+00
# Endometrioid     1.090310e-08         0.001428  1.000000e+00  2.880390e-07
# Endometrioma     1.000000e+00         1.000000  2.880390e-07  1.000000e+00
# Mucinous         3.434752e-03         1.000000  1.827456e-01  2.369325e-02
# Serous           1.000000e+00         1.000000  9.907862e-05  1.000000e+00
#
#                  Mucinous    Serous
# Control          0.003435  1.000000
# Endo-Clear Cell  1.000000  1.000000
# Endometrioid     0.182746  0.000099
# Endometrioma     0.023693  1.000000
# Mucinous         1.000000  0.640376
# Serous           0.640376  1.000000
# Prueba de Dunn para la característica: hsa-miR-6857-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  5.975758e-08  1.588432e-08
# Endo-Clear Cell  1.000000e+00     1.000000e+00  5.171744e-08  1.360359e-08
# Endometrioid     5.975758e-08     5.171744e-08  1.000000e+00  1.000000e+00
# Endometrioma     1.588432e-08     1.360359e-08  1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00     1.000000e+00  5.975758e-08  1.588432e-08
# Serous           1.000000e+00     1.000000e+00  4.311667e-07  1.236371e-07
#
#                      Mucinous        Serous
# Control          1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.000000e+00  1.000000e+00
# Endometrioid     5.975758e-08  4.311667e-07
# Endometrioma     1.588432e-08  1.236371e-07
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-3661
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     2.687975e-10  1.000000e+00  1.000000e+00
# Endo-Clear Cell  2.687975e-10     1.000000e+00  3.987239e-10  3.987239e-10
# Endometrioid     1.000000e+00     3.987239e-10  1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00     3.987239e-10  1.000000e+00  1.000000e+00
# Mucinous         7.601125e-26     6.561021e-04  2.046416e-25  2.046416e-25
# Serous           2.288601e-02     6.701426e-03  2.508468e-02  2.508468e-02
#
#                      Mucinous        Serous
# Control          7.601125e-26  2.288601e-02
# Endo-Clear Cell  6.561021e-04  6.701426e-03
# Endometrioid     2.046416e-25  2.508468e-02
# Endometrioma     2.046416e-25  2.508468e-02
# Mucinous         1.000000e+00  6.560931e-13
# Serous           6.560931e-13  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-3660
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     6.297516e-07  1.000000e+00  1.000000e+00
# Endo-Clear Cell  6.297516e-07     1.000000e+00  8.207516e-07  8.207516e-07
# Endometrioid     1.000000e+00     8.207516e-07  1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00     8.207516e-07  1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00     6.297516e-07  1.000000e+00  1.000000e+00
# Serous           1.000000e+00     1.164605e-05  1.000000e+00  1.000000e+00
#
#                      Mucinous    Serous
# Control          1.000000e+00  1.000000
# Endo-Clear Cell  6.297516e-07  0.000012
# Endometrioid     1.000000e+00  1.000000
# Endometrioma     1.000000e+00  1.000000
# Mucinous         1.000000e+00  1.000000
# Serous           1.000000e+00  1.000000
# Prueba de Dunn para la característica: hsa-miR-873-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00         0.000057  1.357506e-07  3.016209e-09
# Endo-Clear Cell  5.725034e-05         1.000000  1.000000e+00  1.000000e+00
# Endometrioid     1.357506e-07         1.000000  1.000000e+00  1.000000e+00
# Endometrioma     3.016209e-09         1.000000  1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00         0.000013  2.266311e-08  4.218460e-10
# Serous           8.684818e-01         0.104860  1.820234e-03  1.265890e-04
#
#                      Mucinous    Serous
# Control          1.000000e+00  0.868482
# Endo-Clear Cell  1.295156e-05  0.104860
# Endometrioid     2.266311e-08  0.001820
# Endometrioma     4.218460e-10  0.000127
# Mucinous         1.000000e+00  0.424276
# Serous           4.242755e-01  1.000000
# Prueba de Dunn para la característica: hsa-miR-10401-5p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000         0.000535      1.000000      1.000000
# Endo-Clear Cell  0.000535         1.000000      0.000624      0.000624
# Endometrioid     1.000000         0.000624      1.000000      1.000000
# Endometrioma     1.000000         0.000624      1.000000      1.000000
# Mucinous         1.000000         0.000535      1.000000      1.000000
# Serous           1.000000         0.196459      1.000000      1.000000
#
#                  Mucinous    Serous
# Control          1.000000  1.000000
# Endo-Clear Cell  0.000535  0.196459
# Endometrioid     1.000000  1.000000
# Endometrioma     1.000000  1.000000
# Mucinous         1.000000  1.000000
# Serous           1.000000  1.000000
# Prueba de Dunn para la característica: hsa-miR-668-3p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000     8.214783e-03      1.000000  8.154486e-02
# Endo-Clear Cell  0.008215     1.000000e+00      0.812860  7.558592e-09
# Endometrioid     1.000000     8.128598e-01      1.000000  3.360755e-04
# Endometrioma     0.081545     7.558592e-09      0.000336  1.000000e+00
# Mucinous         0.016419     1.000000e+00      1.000000  2.661814e-08
# Serous           1.000000     4.765604e-03      1.000000  1.351579e-01
#
#                      Mucinous    Serous
# Control          1.641852e-02  1.000000
# Endo-Clear Cell  1.000000e+00  0.004766
# Endometrioid     1.000000e+00  1.000000
# Endometrioma     2.661814e-08  0.135158
# Mucinous         1.000000e+00  0.009765
# Serous           9.765258e-03  1.000000
# Prueba de Dunn para la característica: hsa-miR-4748
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  1.000000e+00  9.116012e-07
# Endo-Clear Cell  1.000000e+00     1.000000e+00  1.000000e+00  8.061196e-07
# Endometrioid     1.000000e+00     1.000000e+00  1.000000e+00  1.173325e-06
# Endometrioma     9.116012e-07     8.061196e-07  1.173325e-06  1.000000e+00
# Mucinous         3.680096e-10     3.049000e-10  5.413277e-10  1.000000e+00
# Serous           5.747224e-02     5.534611e-02  6.209738e-02  1.726693e-01
#
#                      Mucinous    Serous
# Control          3.680096e-10  0.057472
# Endo-Clear Cell  3.049000e-10  0.055346
# Endometrioid     5.413277e-10  0.062097
# Endometrioma     1.000000e+00  0.172669
# Mucinous         1.000000e+00  0.002587
# Serous           2.586617e-03  1.000000
# Prueba de Dunn para la característica: hsa-miR-4744
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     4.245534e-08  1.000000e+00  6.680735e-08
# Endo-Clear Cell  4.245534e-08     1.000000e+00  1.928123e-07  1.000000e+00
# Endometrioid     1.000000e+00     1.928123e-07  1.000000e+00  2.904038e-07
# Endometrioma     6.680735e-08     1.000000e+00  2.904038e-07  1.000000e+00
# Mucinous         4.925556e-08     1.000000e+00  2.204985e-07  1.000000e+00
# Serous           3.857731e-05     1.000000e+00  1.217206e-04  1.000000e+00
#
#                      Mucinous    Serous
# Control          4.925556e-08  0.000039
# Endo-Clear Cell  1.000000e+00  1.000000
# Endometrioid     2.204985e-07  0.000122
# Endometrioma     1.000000e+00  1.000000
# Mucinous         1.000000e+00  1.000000
# Serous           1.000000e+00  1.000000
# Prueba de Dunn para la característica: hsa-miR-3659
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  1.000000e+00  4.982316e-09
# Endo-Clear Cell  1.000000e+00     1.000000e+00  1.000000e+00  4.227861e-09
# Endometrioid     1.000000e+00     1.000000e+00  1.000000e+00  6.978824e-09
# Endometrioma     4.982316e-09     4.227861e-09  6.978824e-09  1.000000e+00
# Mucinous         1.000000e+00     1.000000e+00  1.000000e+00  4.982316e-09
# Serous           1.000000e+00     1.000000e+00  1.000000e+00  1.383472e-06
#
#                      Mucinous    Serous
# ...
# Endo-Clear Cell  1.325684e-10     1.000000e+00      0.000004  1.000000e+00
# Endometrioid     1.000000e+00     4.096885e-06      1.000000  2.817998e-05
# Endometrioma     1.986905e-09     1.000000e+00      0.000028  1.000000e+00
# Mucinous         1.000000e+00     4.185900e-16      0.018681  1.408833e-14
# Serous           2.817041e-01     1.375842e-04      1.000000  7.122070e-04
#
#                      Mucinous    Serous
# Control          1.000000e+00  0.281704
# Endo-Clear Cell  4.185900e-16  0.000138
# Endometrioid     1.868096e-02  1.000000
# Endometrioma     1.408833e-14  0.000712
# Mucinous         1.000000e+00  0.001091
# Serous           1.091384e-03  1.000000
# Prueba de Dunn para la característica: ebv-miR-BART13-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioid     1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Mucinous         6.762776e-21     4.580880e-21  1.503572e-20  1.503572e-20
# Serous           1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
#
#                      Mucinous        Serous
# Control          6.762776e-21  1.000000e+00
# Endo-Clear Cell  4.580880e-21  1.000000e+00
# Endometrioid     1.503572e-20  1.000000e+00
# Endometrioma     1.503572e-20  1.000000e+00
# Mucinous         1.000000e+00  2.962584e-19
# Serous           2.962584e-19  1.000000e+00
# Prueba de Dunn para la característica: hsa-let-7b-3p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     4.488544e-07      0.000455  1.835823e-17
# Endo-Clear Cell  4.488544e-07     1.000000e+00      1.000000  1.195279e-02
# Endometrioid     4.549051e-04     1.000000e+00      1.000000  6.256968e-05
# Endometrioma     1.835823e-17     1.195279e-02      0.000063  1.000000e+00
# Mucinous         7.562813e-01     5.205010e-03      0.384965  9.446128e-11
# Serous           4.710163e-04     1.000000e+00      1.000000  5.025245e-05
#
#                      Mucinous    Serous
# Control          7.562813e-01  0.000471
# Endo-Clear Cell  5.205010e-03  1.000000
# Endometrioid     3.849654e-01  1.000000
# Endometrioma     9.446128e-11  0.000050
# Mucinous         1.000000e+00  0.401500
# Serous           4.015004e-01  1.000000
# Prueba de Dunn para la característica: hsa-miR-376a-3p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.372458e-03  2.552870e-07  2.962324e-13
# Endo-Clear Cell  1.372458e-03     1.000000e+00  1.000000e+00  2.129317e-03
# Endometrioid     2.552870e-07     1.000000e+00  1.000000e+00  6.897351e-01
# Endometrioma     2.962324e-13     2.129317e-03  6.897351e-01  1.000000e+00
# Mucinous         2.221626e-19     8.911005e-07  5.245581e-03  1.000000e+00
# Serous           8.972242e-04     1.000000e+00  1.000000e+00  4.075128e-03
#
#                      Mucinous    Serous
# Control          2.221626e-19  0.000897
# Endo-Clear Cell  8.911005e-07  1.000000
# Endometrioid     5.245581e-03  1.000000
# Endometrioma     1.000000e+00  0.004075
# Mucinous         1.000000e+00  0.000002
# Serous           2.386868e-06  1.000000
# Prueba de Dunn para la característica: hsa-miR-551b-3p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     2.224146e-08  1.000000e+00  3.555526e-08
# Endo-Clear Cell  2.224146e-08     1.000000e+00  1.150685e-07  1.000000e+00
# Endometrioid     1.000000e+00     1.150685e-07  1.000000e+00  1.754648e-07
# Endometrioma     3.555526e-08     1.000000e+00  1.754648e-07  1.000000e+00
# Mucinous         2.593767e-08     1.000000e+00  1.321252e-07  1.000000e+00
# Serous           3.829108e-06     1.000000e+00  1.487731e-05  1.000000e+00
#
#                      Mucinous    Serous
# Control          2.593767e-08  0.000004
# Endo-Clear Cell  1.000000e+00  1.000000
# Endometrioid     1.321252e-07  0.000015
# Endometrioma     1.000000e+00  1.000000
# Mucinous         1.000000e+00  1.000000
# Serous           1.000000e+00  1.000000
# Prueba de Dunn para la característica: hsa-miR-6802-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00         0.001834  2.237812e-08  2.237812e-08
# Endo-Clear Cell  1.834004e-03         1.000000  3.562313e-01  3.562313e-01
# Endometrioid     2.237812e-08         0.356231  1.000000e+00  1.000000e+00
# Endometrioma     2.237812e-08         0.356231  1.000000e+00  1.000000e+00
# Mucinous         1.619828e-08         0.338458  1.000000e+00  1.000000e+00
# Serous           8.739532e-02         1.000000  1.523822e-02  1.523822e-02
#
#                      Mucinous    Serous
# Control          1.619828e-08  0.087395
# Endo-Clear Cell  3.384585e-01  1.000000
# Endometrioid     1.000000e+00  0.015238
# Endometrioma     1.000000e+00  0.015238
# Mucinous         1.000000e+00  0.013793
# Serous           1.379265e-02  1.000000
# Prueba de Dunn para la característica: hsa-miR-299-5p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000         1.000000      1.000000      1.000000
# Endo-Clear Cell  1.000000         1.000000      1.000000      1.000000
# Endometrioid     1.000000         1.000000      1.000000      1.000000
# Endometrioma     1.000000         1.000000      1.000000      1.000000
# Mucinous         1.000000         1.000000      1.000000      1.000000
# Serous           0.000009         0.000008      0.000012      0.000012
#
#                  Mucinous    Serous
# Control          1.000000  0.000009
# Endo-Clear Cell  1.000000  0.000008
# Endometrioid     1.000000  0.000012
# Endometrioma     1.000000  0.000012
# Mucinous         1.000000  0.000009
# Serous           0.000009  1.000000
# Prueba de Dunn para la característica: hsa-miR-2467-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  1.271665e-16  1.000000e+00
# Endo-Clear Cell  1.000000e+00     1.000000e+00  9.384554e-17  1.000000e+00
# Endometrioid     1.271665e-16     9.384554e-17  1.000000e+00  2.372243e-16
# Endometrioma     1.000000e+00     1.000000e+00  2.372243e-16  1.000000e+00
# Mucinous         1.000000e+00     1.000000e+00  1.271665e-16  1.000000e+00
# Serous           1.000000e+00     1.000000e+00  7.217744e-14  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.000000e+00  1.000000e+00
# Endometrioid     1.271665e-16  7.217744e-14
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-6802-3p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000         0.000004      0.000005      0.000005
# Endo-Clear Cell  0.000004         1.000000      1.000000      1.000000
# Endometrioid     0.000005         1.000000      1.000000      1.000000
# Endometrioma     0.000005         1.000000      1.000000      1.000000
# Mucinous         0.000004         1.000000      1.000000      1.000000
# Serous           0.003431         1.000000      1.000000      1.000000
#
#                  Mucinous    Serous
# Control          0.000004  0.003431
# Endo-Clear Cell  1.000000  1.000000
# Endometrioid     1.000000  1.000000
# Endometrioma     1.000000  1.000000
# Mucinous         1.000000  1.000000
# Serous           1.000000  1.000000
# Prueba de Dunn para la característica: hsa-miR-7161-3p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioid     1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
# Mucinous         1.230019e-21     8.216364e-22  2.814048e-21  2.814048e-21
# Serous           1.000000e+00     1.000000e+00  1.000000e+00  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.230019e-21  1.000000e+00
# Endo-Clear Cell  8.216364e-22  1.000000e+00
# Endometrioid     2.814048e-21  1.000000e+00
# Endometrioma     2.814048e-21  1.000000e+00
# Mucinous         1.000000e+00  1.853975e-21
# Serous           1.853975e-21  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-1304-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.142244e-08      0.007539  1.000000e+00
# Endo-Clear Cell  1.142244e-08     1.000000e+00      0.137207  9.970056e-10
# Endometrioid     7.539461e-03     1.372065e-01      1.000000  1.609958e-03
# Endometrioma     1.000000e+00     9.970056e-10      0.001610  1.000000e+00
# Mucinous         3.025246e-11     1.000000e+00      0.007135  2.039907e-12
# Serous           2.112804e-04     1.000000e+00      1.000000  3.353922e-05
#
#                      Mucinous    Serous
# Control          3.025246e-11  0.000211
# Endo-Clear Cell  1.000000e+00  1.000000
# Endometrioid     7.134793e-03  1.000000
# Endometrioma     2.039907e-12  0.000034
# Mucinous         1.000000e+00  0.116803
# Serous           1.168028e-01  1.000000
# Prueba de Dunn para la característica: hsa-miR-6850-5p
#                   Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000         0.550197      0.035674      1.000000
# Endo-Clear Cell  0.550197         1.000000      1.000000      0.036278
# Endometrioid     0.035674         1.000000      1.000000      0.001110
# Endometrioma     1.000000         0.036278      0.001110      1.000000
# Mucinous         1.000000         1.000000      0.290021      1.000000
# Serous           1.000000         1.000000      1.000000      0.093244
#
#                  Mucinous    Serous
# Control          1.000000  1.000000
# Endo-Clear Cell  1.000000  1.000000
# Endometrioid     0.290021  1.000000
# Endometrioma     1.000000  0.093244
# Mucinous         1.000000  1.000000
# Serous           1.000000  1.000000
# Prueba de Dunn para la característica: hsa-miR-99b-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.348669e-17      0.000481  9.176997e-20
# Endo-Clear Cell  1.348669e-17     1.000000e+00      0.000065  1.000000e+00
# Endometrioid     4.808604e-04     6.463618e-05      1.000000  3.225491e-06
# Endometrioma     9.176997e-20     1.000000e+00      0.000003  1.000000e+00
# Mucinous         7.971773e-01     7.515867e-11      0.375338  1.196840e-12
# Serous           3.801872e-07     1.951381e-02      1.000000  1.959774e-03
#
#                      Mucinous        Serous
# Control          7.971773e-01  3.801872e-07
# Endo-Clear Cell  7.515867e-11  1.951381e-02
# Endometrioid     3.753382e-01  1.000000e+00
# Endometrioma     1.196840e-12  1.959774e-03
# Mucinous         1.000000e+00  4.006498e-03
# Serous           4.006498e-03  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-6512-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  6.593342e-15  1.000000e+00
# Endo-Clear Cell  1.000000e+00     1.000000e+00  5.022146e-15  1.000000e+00
# Endometrioid     6.593342e-15     5.022146e-15  1.000000e+00  1.152645e-14
# Endometrioma     1.000000e+00     1.000000e+00  1.152645e-14  1.000000e+00
# Mucinous         1.000000e+00     1.000000e+00  6.593342e-15  1.000000e+00
# Serous           1.000000e+00     1.000000e+00  2.168357e-13  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.000000e+00  1.000000e+00
# Endometrioid     6.593342e-15  2.168357e-13
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-6718-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     2.911613e-11      0.000234      0.000686
# Endo-Clear Cell  2.911613e-11     1.000000e+00      0.124236      0.058635
# Endometrioid     2.336082e-04     1.242358e-01      1.000000      1.000000
# Endometrioma     6.863019e-04     5.863499e-02      1.000000      1.000000
# Mucinous         1.021832e-12     1.000000e+00      0.028324      0.012062
# Serous           1.000000e+00     6.428045e-07      0.078693      0.162310
#
#                      Mucinous        Serous
# Control          1.021832e-12  1.000000e+00
# Endo-Clear Cell  1.000000e+00  6.428045e-07
# Endometrioid     2.832351e-02  7.869278e-02
# Endometrioma     1.206241e-02  1.623099e-01
# Mucinous         1.000000e+00  4.380248e-08
# Serous           4.380248e-08  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-520h
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.000000e+00  1.225440e-15  1.000000e+00
# Endo-Clear Cell  1.000000e+00     1.000000e+00  9.209179e-16  1.000000e+00
# Endometrioid     1.225440e-15     9.209179e-16  1.000000e+00  2.202390e-15
# Endometrioma     1.000000e+00     1.000000e+00  2.202390e-15  1.000000e+00
# Mucinous         1.000000e+00     1.000000e+00  1.225440e-15  1.000000e+00
# Serous           1.000000e+00     1.000000e+00  1.638694e-15  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.000000e+00  1.000000e+00
# Endometrioid     1.225440e-15  1.638694e-15
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-5586-3p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     1.086280e-11  1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.086280e-11     1.000000e+00  1.700398e-11  1.700398e-11
# Endometrioid     1.000000e+00     1.700398e-11  1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00     1.700398e-11  1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00     1.086280e-11  1.000000e+00  1.000000e+00
# Serous           1.000000e+00     1.356525e-11  1.000000e+00  1.000000e+00
#
#                      Mucinous        Serous
# Control          1.000000e+00  1.000000e+00
# Endo-Clear Cell  1.086280e-11  1.356525e-11
# Endometrioid     1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00
# Prueba de Dunn para la característica: hsa-miR-29a-5p
#                       Control  Endo-Clear Cell  Endometrioid  Endometrioma  \
# Control          1.000000e+00     5.815075e-14  1.274278e-13  1.274278e-13
# Endo-Clear Cell  5.815075e-14     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioid     1.274278e-13     1.000000e+00  1.000000e+00  1.000000e+00
# Endometrioma     1.274278e-13     1.000000e+00  1.000000e+00  1.000000e+00
# Mucinous         7.519998e-14     1.000000e+00  1.000000e+00  1.000000e+00
# Serous           3.222701e-10     1.000000e+00  1.000000e+00  1.000000e+00
#
#                      Mucinous        Serous
# Control          7.519998e-14  3.222701e-10
# Endo-Clear Cell  1.000000e+00  1.000000e+00
# Endometrioid     1.000000e+00  1.000000e+00
# Endometrioma     1.000000e+00  1.000000e+00
# Mucinous         1.000000e+00  1.000000e+00
# Serous           1.000000e+00  1.000000e+00

# %%
variablesDunn = []

for clas1 in  df.Desc.unique():
    resultados = {}
    
    listado = df.Desc.unique().tolist()
    listado.remove(clas1)
    
    for clas2 in listado:
        # Inicializar una lista para las dos características con los menores p-values
        resultados[clas2] = [(None, 1), (None, 1), (None, 1)]  # Aquí guardaremos las dos mejores
        
        for x, y in dunn_results.items():
            # Obtener el valor p para las comparaciones entre clas1 y clas2
            valor = y[clas1][clas2]
            
            # Si el p-value es menor que el tercer menor valor actual, lo insertamos en la lista
            if valor < resultados[clas2][2][1]:  # Comparamos con el tercer menor
                # Insertar y ordenar los dos menores p-values
                resultados[clas2].append((x, valor))
                resultados[clas2] = sorted(resultados[clas2], key=lambda z: z[1])[:3]

    print(resultados)
    variablesDunn.extend([x[0][0] for x in resultados.values()])
    variablesDunn.extend([x[1][0] for x in resultados.values()])
    variablesDunn.extend([x[2][0] for x in resultados.values()])
# Out:
# {'Mucinous': [('hcmv-miR-US33-5p', 5.0216907535853e-28), ('hsa-miR-3165', 4.223695957649604e-27), ('hsa-miR-6881-3p', 1.543207500824564e-21)], 'Endometrioid': [('hsa-miR-449c-5p', 1.2188484131999795e-26), ('hsa-miR-6715b-3p', 9.07000172784831e-26), ('hsa-miR-4701-5p', 7.795216855013845e-19)], 'Control': [('hsa-miR-23b-3p', 1.59202242295708e-20), ('hsa-miR-1293', 5.0102248446230034e-20), ('hsa-miR-484', 1.7955247637638325e-18)], 'Endometrioma': [('hsa-miR-1193', 5.393808436980067e-23), ('hsa-miR-7151-5p', 2.6674487414356474e-22), ('hsa-miR-7109-3p', 1.6386938203980988e-15)], 'Endo-Clear Cell': [('hsa-miR-4715-5p', 2.1574967502450684e-23), ('hsa-miR-3131', 7.62769246628928e-18), ('hsa-miR-153-3p', 1.483563165888275e-17)]}
# {'Serous': [('hcmv-miR-US33-5p', 5.0216907535853e-28), ('hsa-miR-3165', 4.223695957649604e-27), ('hsa-miR-6881-3p', 1.543207500824564e-21)], 'Endometrioid': [('hcmv-miR-US33-5p', 1.4731821470177441e-33), ('hsa-miR-3165', 1.1566409127340133e-32), ('hsa-miR-6881-3p', 1.1261126988658379e-30)], 'Control': [('hcmv-miR-US33-5p', 3.96987255554022e-34), ('hsa-miR-126-5p', 3.20592459056557e-33), ('hsa-miR-3165', 3.2288545792382e-33)], 'Endometrioma': [('hcmv-miR-US33-5p', 1.4731821470177441e-33), ('hsa-miR-3165', 1.1566409127340133e-32), ('hsa-miR-6881-3p', 1.1261126988658379e-30)], 'Endo-Clear Cell': [('hcmv-miR-US33-5p', 2.0946838427875525e-34), ('hsa-miR-3165', 1.7332661621899635e-33), ('hsa-miR-6881-3p', 1.8962739942603975e-31)]}
# {'Serous': [('hsa-miR-449c-5p', 1.2188484131999795e-26), ('hsa-miR-6715b-3p', 9.07000172784831e-26), ('hsa-miR-4701-5p', 7.795216855013845e-19)], 'Mucinous': [('hcmv-miR-US33-5p', 1.4731821470177441e-33), ('hsa-miR-3165', 1.1566409127340133e-32), ('hsa-miR-6881-3p', 1.1261126988658379e-30)], 'Control': [('hsa-miR-340-5p', 5.005975185681869e-38), ('hsa-miR-126-5p', 3.065835233346497e-35), ('hsa-miR-27b-3p', 4.421225257313944e-32)], 'Endometrioma': [('hsa-miR-323b-3p', 4.288099189755661e-35), ('hsa-miR-337-3p', 1.9571769677400572e-30), ('hsa-miR-6715b-3p', 1.4991174586134727e-29)], 'Endo-Clear Cell': [('hsa-miR-6715b-3p', 2.776603921460023e-30), ('hsa-miR-4701-5p', 3.398623455063666e-28), ('hsa-miR-4715-5p', 4.076634238643743e-26)]}
# {'Serous': [('hsa-miR-23b-3p', 1.59202242295708e-20), ('hsa-miR-1293', 5.0102248446230034e-20), ('hsa-miR-484', 1.7955247637638325e-18)], 'Mucinous': [('hcmv-miR-US33-5p', 3.96987255554022e-34), ('hsa-miR-126-5p', 3.20592459056557e-33), ('hsa-miR-3165', 3.2288545792382e-33)], 'Endometrioid': [('hsa-miR-340-5p', 5.005975185681869e-38), ('hsa-miR-126-5p', 3.065835233346497e-35), ('hsa-miR-27b-3p', 4.421225257313944e-32)], 'Endometrioma': [('hsa-miR-7151-5p', 1.502090691747978e-26), ('hsa-miR-1193', 1.463593264365309e-24), ('hsa-miR-369-5p', 2.45693630066169e-24)], 'Endo-Clear Cell': [('hsa-miR-641', 1.057504659285811e-27), ('hsa-miR-4715-5p', 1.4606688792211007e-26), ('hsa-miR-10a-3p', 1.0714630243144098e-23)]}
# {'Serous': [('hsa-miR-1193', 5.393808436980067e-23), ('hsa-miR-7151-5p', 2.6674487414356474e-22), ('hsa-miR-7109-3p', 1.6386938203980988e-15)], 'Mucinous': [('hcmv-miR-US33-5p', 1.4731821470177441e-33), ('hsa-miR-3165', 1.1566409127340133e-32), ('hsa-miR-6881-3p', 1.1261126988658379e-30)], 'Endometrioid': [('hsa-miR-323b-3p', 4.288099189755661e-35), ('hsa-miR-337-3p', 1.9571769677400572e-30), ('hsa-miR-6715b-3p', 1.4991174586134727e-29)], 'Control': [('hsa-miR-7151-5p', 1.502090691747978e-26), ('hsa-miR-1193', 1.463593264365309e-24), ('hsa-miR-369-5p', 2.45693630066169e-24)], 'Endo-Clear Cell': [('hsa-miR-7151-5p', 9.223627402210215e-27), ('hsa-miR-4715-5p', 4.076634238643743e-26), ('hsa-miR-1193', 9.324929888849095e-25)]}
# {'Serous': [('hsa-miR-4715-5p', 2.1574967502450684e-23), ('hsa-miR-3131', 7.62769246628928e-18), ('hsa-miR-153-3p', 1.483563165888275e-17)], 'Mucinous': [('hcmv-miR-US33-5p', 2.0946838427875525e-34), ('hsa-miR-3165', 1.7332661621899635e-33), ('hsa-miR-6881-3p', 1.8962739942603975e-31)], 'Endometrioid': [('hsa-miR-6715b-3p', 2.776603921460023e-30), ('hsa-miR-4701-5p', 3.398623455063666e-28), ('hsa-miR-4715-5p', 4.076634238643743e-26)], 'Control': [('hsa-miR-641', 1.057504659285811e-27), ('hsa-miR-4715-5p', 1.4606688792211007e-26), ('hsa-miR-10a-3p', 1.0714630243144098e-23)], 'Endometrioma': [('hsa-miR-7151-5p', 9.223627402210215e-27), ('hsa-miR-4715-5p', 4.076634238643743e-26), ('hsa-miR-1193', 9.324929888849095e-25)]}

# %%
variablesDunn = list(set(variablesDunn))
print(f'VariablesDunn: \n\n{variablesDunn}')
print(f'\nTotal de biomarcadores: {len(variablesDunn)}')
# Out:
# VariablesDunn:
#
# ['hsa-miR-449c-5p', 'hcmv-miR-US33-5p', 'hsa-miR-10a-3p', 'hsa-miR-1293', 'hsa-miR-323b-3p', 'hsa-miR-3165', 'hsa-miR-641', 'hsa-miR-23b-3p', 'hsa-miR-153-3p', 'hsa-miR-1193', 'hsa-miR-340-5p', 'hsa-miR-4715-5p', 'hsa-miR-7109-3p', 'hsa-miR-126-5p', 'hsa-miR-7151-5p', 'hsa-miR-484', 'hsa-miR-337-3p', 'hsa-miR-369-5p', 'hsa-miR-3131', 'hsa-miR-6881-3p', 'hsa-miR-4701-5p', 'hsa-miR-27b-3p', 'hsa-miR-6715b-3p']
#
# Total de biomarcadores: 23

# %% [markdown]
# **Modifico dataframe de estudio**

# %%
df_study = pd.concat([df_study.iloc[:,:5],df_study[variablesDunn]], axis=1)
df_study.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Ordeno variables por p-value en orden descendente

# %%
# Separar las características y la variable objetivo
X = df_study.iloc[:,5:]
y = df_study['Desc']

# Aplicar la prueba de Kruskal-Wallis a cada característica
p_values = []
for column in X.columns:
    # Obtener las muestras para cada clase
    samples = [X[column][y == cls].values for cls in y.unique()]
    stat, p_value = kruskal(*samples)
    p_values.append((column, p_value))

# %%
p_values_sorted = sorted(p_values, key=lambda x: x[1])
variables_sorted = [x[0] for x in p_values_sorted]

print (f'p_value máximo: {p_values_sorted[-1]}')
print (f'Total de variables: {len(variables_sorted)}')
# Out:
# p_value máximo: ('hsa-miR-7109-3p', 5.308214608288803e-23)
# Total de variables: 23

# %% [markdown]
# **Guardo dataframe**

# %%
df_study = pd.concat([df_study.iloc[:,:5],df_study[variables_sorted]],axis=1)
df_study.to_csv('./data/Cluster_serum.csv', index=False)

# %% [markdown]
# ### Prueba U Mann entre matrices de cancer y sin cancer

# %%
combinaciones = list(combinations(df_conjunto.Desc.unique(),2))
combinaciones
# Out:
# [('Healthy Control', 'Colorectal Cancer'),
#  ('Healthy Control', 'Prostate Cancer'),
#  ('Healthy Control', 'Pancreatic Cancer'),
#  ('Healthy Control', 'Metastatic renal cell carcinoma (mRCC)'),
#  ('Healthy Control', 'chronic fatigue syndrome'),
#  ('Healthy Control', 'non-fatigued'),
#  ('Colorectal Cancer', 'Prostate Cancer'),
#  ('Colorectal Cancer', 'Pancreatic Cancer'),
#  ('Colorectal Cancer', 'Metastatic renal cell carcinoma (mRCC)'),
#  ('Colorectal Cancer', 'chronic fatigue syndrome'),
#  ('Colorectal Cancer', 'non-fatigued'),
#  ('Prostate Cancer', 'Pancreatic Cancer'),
#  ('Prostate Cancer', 'Metastatic renal cell carcinoma (mRCC)'),
#  ('Prostate Cancer', 'chronic fatigue syndrome'),
#  ('Prostate Cancer', 'non-fatigued'),
#  ('Pancreatic Cancer', 'Metastatic renal cell carcinoma (mRCC)'),
#  ('Pancreatic Cancer', 'chronic fatigue syndrome'),
#  ('Pancreatic Cancer', 'non-fatigued'),
#  ('Metastatic renal cell carcinoma (mRCC)', 'chronic fatigue syndrome'),
#  ('Metastatic renal cell carcinoma (mRCC)', 'non-fatigued'),
#  ('chronic fatigue syndrome', 'non-fatigued')]

# %%
from scipy.stats import mannwhitneyu

def u_mann(x, y, valor):
    grupo_1 = df_conjunto[df_conjunto.Desc==x].iloc[:,6:]
    grupo_2 = df_conjunto[df_conjunto.Desc==y].iloc[:,6:]
    u_man=[]
    for x in grupo_1.columns:
        stat, p_value = mannwhitneyu(grupo_1[x], grupo_2[x])
    
        u_man.append((x,p_value))
    u_man_sorted = sorted(u_man, key=lambda x: x[1])
    u_man_filter = [x for x in u_man_sorted if x[1]<valor]
    columnas_filtradas = [x[0] for x in u_man_filter]
    return columnas_filtradas

# %%
frecuencia = {}
for feature in df_conjunto.iloc[:,6:].columns.tolist():
    frecuencia[feature] = 0

for comb in combinaciones:
    columnas_filtradas = u_mann(comb[0],comb[1],5.e-3)
    for variable in columnas_filtradas:
        frecuencia[variable] += 1

# %%
frecuencia_sort = sorted(frecuencia.items(), key=lambda x: x[1], reverse=True)
columnas_filtradas = [x[0] for x in frecuencia_sort if x[1]>int(len(combinacion)*0.80)]
print(len(columnas_filtradas))
# Out:
# 32

# %% [markdown]
# #### Guardo df_cluster

# %%
df_cluster = df_conjunto.loc[:, df_conjunto.iloc[:,:6].columns.tolist() + columnas_filtradas]
df_cluster.reset_index(drop=True, inplace=True)

# %%
df_cluster.to_csv('./data/Cluster_plasma.csv', index=False)

# %% [markdown]
# ### Clustermap

# %%
df_cluster= load('./data/Cluster_serum.csv')

# %%
# Definir la subcarpeta de figuras
subcarpeta_figuras = 'figures/serum'
os.makedirs(subcarpeta_figuras, exist_ok=True)

# Filtrar las clases únicas en 'Desc'
clases = df_cluster.Desc.unique()

# Calcular la media de cada variable para cada clase de 'Desc'
df_means = df_cluster.iloc[:,4:].groupby('Desc').mean()

# Crear un clustermap basado en las medias por clase, sin la barra de colores superior
sns.clustermap(df_means, col_cluster=False, cbar_kws={"orientation": "vertical"}, row_cluster=True)

# Configurar el título
plt.title('Cluster Map de Medias por Clase de Desc')

# Guardar y mostrar el gráfico
plt.savefig(f'./{subcarpeta_figuras}/clustermap_means.png', bbox_inches='tight')
plt.show()

# %%
#Subcarpeta modelo
subcarpeta_figuras='figures/serum'

if os.path.exists(subcarpeta_figuras):
    pass
else:
    os.mkdir(subcarpeta_figuras)

# Filtrar las clases únicas en 'Desc'
clases = df_cluster.Desc.unique()

for i, clas in enumerate(clases):
    print(clas)
    df_filter = df_cluster[df_cluster.Desc == clas].copy()

    exo_palette = {True: 'blue', False: 'red'}
    row_colors = df_filter['Exosome'].map(exo_palette)

    # Crear un clustermap para cada clase (no se puede usar `ax`)
    sns.clustermap(df_filter[variables_sorted], col_cluster=False, cbar_kws={"orientation": "vertical"}, row_cluster=True, row_colors=row_colors)
    #sns.clustermap(df_filter[variables], col_cluster=False, cbar_kws={"orientation": "vertical"}, row_cluster=True, row_colors=row_colors)
    
    # Configurar el título
    plt.suptitle(f'Cluster para {clas}')
    plt.savefig(f'./{subcarpeta_figuras}/clustermap_{clas}.png', bbox_inches='tight')
    
    # Mostrar el gráfico
    plt.show()
# Out:
# Serous
# Mucinous
# Endometrioid
# Control
# Endometrioma
# Endo-Clear Cell

# %% [markdown]
# ## Distribucion

# %%
g = sns.catplot(df_study, kind='box',col='Desc',col_wrap=5, orient='v', sharey=False)

# Rotar etiquetas del eje x
for ax in g.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(45)
        label.set_ha('right')  # Opcional: para alinear mejor las etiquetas

    
plt.savefig(f'./figures/serum/boxplot_variables.png', bbox_inches='tight')
plt.show()
# Out:
# C:\Users\eagle\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Filtramos las columnas que contienen los valores de microARN
microRNA_columns = df_study.columns[5:]  # Ajustar según las columnas de tu dataframe

# Crear una figura con subplots
fig, axes = plt.subplots(len(microRNA_columns), figsize=(15, len(microRNA_columns) * 5), sharey=True)

# Iterar sobre cada valor único de 'Sex' y cada microRNA
for i, feature in enumerate(microRNA_columns):
    sns.boxplot(x='Desc', y=feature, data=df_study, ax=axes[i])
    axes[i].set_xlabel('Desc')
    axes[i].set_ylabel(feature)

    # Rotar las etiquetas del eje x 45 grados
    axes[i].tick_params(axis='x', rotation=45)
     
# Ajustar el layout para que no haya superposición
plt.tight_layout()
plt.savefig(f'./figures/serum/boxplot_Desc.png', bbox_inches='tight')
plt.show()
